# %% [markdown]
# # Python Basics

# %% [markdown]
# 1.What is Python, and why is it popular?
#    - Python is a programming language that is easy to understand and write,making it a popular choice among developer and programmers.It is compatible with various programming paradigms,such as produceral object-orientend,and function programming.

# %%
jkwebf
